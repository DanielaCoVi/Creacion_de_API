# %% [markdown]
# #### *Rol: Data Engineer*
#
# # <center>  *Exploratory Data Analysis*(EDA) - *Extract Transform and Load*(ETL) </center>
# ### Proyecto Individual
# ---

# %% [markdown]
# ##### Revisamos los datos que nos llegan, leeremos los archivos CSV que nos brindan en esta consigna y vamos intentando comprender “¿de qué se trata?”, vislumbrando posibles patrones y reconociendo distribuciones estadísticas que puedan ser útiles en el futuro.
#
# #### >>><center> **Consigna :** ```Elaborar las transformaciones requeridas para luego disponibilizar los datos mediante la elaboración y ejecución de una API.``` </center>
#
# ---
#
# ### **Requerimientos para nuestra transformación de datos:**
#
# #####  1. Generar campo id: Cada id se compondrá de la primera letra del nombre de la plataforma, seguido del show_id ya presente en los datasets (ejemplo para títulos de Amazon = as123)
# #####  2. Los valores nulos del campo rating deberán reemplazarse por el string “G” (corresponde al maturity rating: “general for all audiences”
# #####  3. De haber fechas, deberán tener el formato AAAA-mm-dd
# #####  4. Los campos de texto deberán estar en minúsculas, sin excepciones
# #####  5. El campo duration debe convertirse en dos campos: duration_int y duration_type. El primero será un integer y el segundo un string indicando la unidad de medición de duración: min (minutos) o   season (temporadas)

# %%
import pandas as pd

# %% [markdown]
# ### - Leemos cada dataset con la libreria pandas(formato: CSV).

# %% [markdown]
# ### Dataset *'Amazon'*

# %%
amazon_prime = pd.read_csv('https://raw.githubusercontent.com/HX-FNegrete/PI01-Data-Engineering/main/Datasets/amazon_prime_titles-score.csv')
    
"""
Vamos revisando las columnas con las que contamos.
"""
amazon_prime.head()
# Out:
#   show_id   type                 title        director  \
# 0      s1  Movie   The Grand Seduction    Don McKellar
# 1      s2  Movie  Take Care Good Night    Girish Joshi
# 2      s3  Movie  Secrets of Deception     Josh Webber
# 3      s4  Movie    Pink: Staying True  Sonia Anderson
# 4      s5  Movie         Monster Maker    Giles Foster
#
#                                                 cast         country  \
# 0     Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# 1   Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar           India
# 2  Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...   United States
# 3  Interviews with: Pink, Adele, Beyoncé, Britney...   United States
# 4  Harry Dean Stanton, Kieran O'Brien, George Cos...  United Kingdom
#
#        date_added  release_year rating duration                listed_in  \
# 0  March 30, 2021          2014    NaN  113 min            Comedy, Drama
# 1  March 30, 2021          2018    13+  110 min     Drama, International
# 2  March 30, 2021          2017    NaN   74 min  Action, Drama, Suspense
# 3  March 30, 2021          2014    NaN   69 min              Documentary
# 4  March 30, 2021          1989    NaN   45 min           Drama, Fantasy
#
#                                          description  score
# 0  A small fishing village must procure a local d...     99
# 1  A Metro Family decides to fight a Cyber Crimin...     37
# 2  After a man discovers his wife is cheating on ...     20
# 3  Pink breaks the mold once again, bringing her ...     27
# 4  Teenage Matt Banting wants to work with a famo...     75

# %% [markdown]
# #### - Detallamos la forma de nuestro Dataframe

# %%
print('Cantidad de Filas y columnas:',amazon_prime.shape)
# Out:
# Cantidad de Filas y columnas: (9668, 13)

# %% [markdown]
# #### - Vamos viendo a detalle los nombres de nuestras columnas

# %%
print('Nombre columnas:',amazon_prime.columns)
# Out:
# Nombre columnas: Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description',
#        'score'],
#       dtype='object')

# %% [markdown]
# #### - Vemos cuantos datos nulos se encuentran en cada columna

# %%
amazon_prime.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2082
# cast            1233
# country         8996
# date_added      9513
# release_year       0
# rating           337
# duration           0
# listed_in          0
# description        0
# score              0
# dtype: int64

# %% [markdown]
# ## .info()
# #### - Imprime un resumen conciso de un DataFrame; este método imprime información sobre un DataFrame, incluido el tipo de índice y las columnas, los valores no nulos y el uso de la memoria.

# %%
amazon_prime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9668 entries, 0 to 9667
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       9668 non-null   object
#  1   type          9668 non-null   object
#  2   title         9668 non-null   object
#  3   director      7586 non-null   object
#  4   cast          8435 non-null   object
#  5   country       672 non-null    object
#  6   date_added    155 non-null    object
#  7   release_year  9668 non-null   int64
#  8   rating        9331 non-null   object
#  9   duration      9668 non-null   object
#  10  listed_in     9668 non-null   object
#  11  description   9668 non-null   object
#  12  score         9668 non-null   int64
# dtypes: int64(2), object(11)
# memory usage: 982.0+ KB

# %% [markdown]
# #### ``` 1. Generando campo id = "a" + show_id ```

# %%
amazon_prime["show_id"] = amazon_prime["show_id"].apply(lambda x: "a" + x)
amazon_prime.head()
# Out:
#   show_id   type                 title        director  \
# 0     as1  Movie   The Grand Seduction    Don McKellar
# 1     as2  Movie  Take Care Good Night    Girish Joshi
# 2     as3  Movie  Secrets of Deception     Josh Webber
# 3     as4  Movie    Pink: Staying True  Sonia Anderson
# 4     as5  Movie         Monster Maker    Giles Foster
#
#                                                 cast         country  \
# 0     Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# 1   Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar           India
# 2  Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...   United States
# 3  Interviews with: Pink, Adele, Beyoncé, Britney...   United States
# 4  Harry Dean Stanton, Kieran O'Brien, George Cos...  United Kingdom
#
#        date_added  release_year rating duration                listed_in  \
# 0  March 30, 2021          2014    NaN  113 min            Comedy, Drama
# 1  March 30, 2021          2018    13+  110 min     Drama, International
# 2  March 30, 2021          2017    NaN   74 min  Action, Drama, Suspense
# 3  March 30, 2021          2014    NaN   69 min              Documentary
# 4  March 30, 2021          1989    NaN   45 min           Drama, Fantasy
#
#                                          description  score
# 0  A small fishing village must procure a local d...     99
# 1  A Metro Family decides to fight a Cyber Crimin...     37
# 2  After a man discovers his wife is cheating on ...     20
# 3  Pink breaks the mold once again, bringing her ...     27
# 4  Teenage Matt Banting wants to work with a famo...     75

# %% [markdown]
# #### ```2. Reemplazando los valores nulos del campo 'rating' por el string “g” ```

# %%
amazon_prime['rating'].fillna('g', inplace=True)

# %% [markdown]
# #### Verificando que se hayan reemplazado todos los valores nulos:

# %%
amazon_prime['rating'].isna().count()
# Out:
# 9668

# %% [markdown]
# #### ``` 3. De haber fechas, deberán tener el formato AAAA-mm-dd ```

# %%
amazon_prime['date_added'] = pd.to_datetime(amazon_prime['date_added'], format='%B %d, %Y').dt.strftime('%Y-%m-%d')

# %% [markdown]
# #### Verificando cambio de formato en la columna 'date_added'

# %%
amazon_prime.head(10)
# Out:
#   show_id   type                  title                     director  \
# 0     as1  Movie    The Grand Seduction                 Don McKellar
# 1     as2  Movie   Take Care Good Night                 Girish Joshi
# 2     as3  Movie   Secrets of Deception                  Josh Webber
# 3     as4  Movie     Pink: Staying True               Sonia Anderson
# 4     as5  Movie          Monster Maker                 Giles Foster
# 5     as6  Movie  Living With Dinosaurs                 Paul Weiland
# 6     as7  Movie              Hired Gun                  Fran Strine
# 7     as8  Movie           Grease Live!  Thomas Kail, Alex Rudzinski
# 8     as9  Movie        Global Meltdown                Daniel Gilboy
# 9    as10  Movie         David's Mother        Robert Allan Ackerman
#
#                                                 cast         country  \
# 0     Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# 1   Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar           India
# 2  Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...   United States
# 3  Interviews with: Pink, Adele, Beyoncé, Britney...   United States
# 4  Harry Dean Stanton, Kieran O'Brien, George Cos...  United Kingdom
# 5  Gregory Chisholm, Juliet Stevenson, Brian Hens...  United Kingdom
# 6  Alice Cooper, Liberty DeVitto, Ray Parker Jr.,...   United States
# 7  Julianne Hough, Aaron Tveit, Vanessa Hudgens, ...   United States
# 8  Michael Paré, Leanne Khol Young, Patrick J. Ma...          Canada
# 9    Kirstie Alley, Sam Waterston, Stockard Channing   United States
#
#    date_added  release_year rating duration  \
# 0  2021-03-30          2014      g  113 min
# 1  2021-03-30          2018    13+  110 min
# 2  2021-03-30          2017      g   74 min
# 3  2021-03-30          2014      g   69 min
# 4  2021-03-30          1989      g   45 min
# 5  2021-03-30          1989      g   52 min
# 6  2021-03-30          2017      g   98 min
# 7  2021-03-30          2016      g  131 min
# 8  2021-03-30          2017      g   87 min
# 9  2021-04-01          1994      g   92 min
#
#                            listed_in  \
# 0                      Comedy, Drama
# 1               Drama, International
# 2            Action, Drama, Suspense
# 3                        Documentary
# 4                     Drama, Fantasy
# 5                      Fantasy, Kids
# 6      Documentary, Special Interest
# 7                             Comedy
# 8  Action, Science Fiction, Suspense
# 9                              Drama
#
#                                          description  score
# 0  A small fishing village must procure a local d...     99
# 1  A Metro Family decides to fight a Cyber Crimin...     37
# 2  After a man discovers his wife is cheating on ...     20
# 3  Pink breaks the mold once again, bringing her ...     27
# 4  Teenage Matt Banting wants to work with a famo...     75
# 5  The story unfolds in a an English seaside town...     74
# 6  They are the "First Call, A-list" musicians, j...     50
# 7  This honest, uncompromising comedy chronicles ...     84
# 8  A helicopter pilot and an environmental scient...     46
# 9  Sally Goodson is a devoted mother to her autis...     70

# %% [markdown]
# #### ``` 4. Los campos de texto deberán estar en minúsculas, sin excepciones ```

# %%
amazon = amazon_prime.applymap(lambda x: str(x).lower() if type(x) == str else x)

# %% [markdown]
# #### Verificando

# %%
amazon.head()
# Out:
#   show_id   type                 title        director  \
# 0     as1  movie   the grand seduction    don mckellar
# 1     as2  movie  take care good night    girish joshi
# 2     as3  movie  secrets of deception     josh webber
# 3     as4  movie    pink: staying true  sonia anderson
# 4     as5  movie         monster maker    giles foster
#
#                                                 cast         country  \
# 0     brendan gleeson, taylor kitsch, gordon pinsent          canada
# 1   mahesh manjrekar, abhay mahajan, sachin khedekar           india
# 2  tom sizemore, lorenzo lamas, robert lasardo, r...   united states
# 3  interviews with: pink, adele, beyoncé, britney...   united states
# 4  harry dean stanton, kieran o'brien, george cos...  united kingdom
#
#    date_added  release_year rating duration                listed_in  \
# 0  2021-03-30          2014      g  113 min            comedy, drama
# 1  2021-03-30          2018    13+  110 min     drama, international
# 2  2021-03-30          2017      g   74 min  action, drama, suspense
# 3  2021-03-30          2014      g   69 min              documentary
# 4  2021-03-30          1989      g   45 min           drama, fantasy
#
#                                          description  score
# 0  a small fishing village must procure a local d...     99
# 1  a metro family decides to fight a cyber crimin...     37
# 2  after a man discovers his wife is cheating on ...     20
# 3  pink breaks the mold once again, bringing her ...     27
# 4  teenage matt banting wants to work with a famo...     75

# %% [markdown]
# #### ``` 5. El campo duration debe convertirse en dos campos: duration_int y duration_type. El primero será un integer y el segundo un string indicando la unidad de medición de duración: min (minutos) o season (temporadas) ```

# %% [markdown]
# #### Cambiando seasons a season

# %%
amazon['duration'] = amazon['duration'].str.replace('seasons', 'season')

# %% [markdown]
# #### Transformando 'duration' a 'duration_int','duration_type'

# %%
amazon[['duration_int','duration_type']] = amazon['duration'].str.split(n=1,expand=True)
amazon['duration_int'] = amazon['duration_int'].astype(int)

# %% [markdown]
# #### Verificando

# %%
amazon.head()
# Out:
#   show_id   type                 title        director  \
# 0     as1  movie   the grand seduction    don mckellar
# 1     as2  movie  take care good night    girish joshi
# 2     as3  movie  secrets of deception     josh webber
# 3     as4  movie    pink: staying true  sonia anderson
# 4     as5  movie         monster maker    giles foster
#
#                                                 cast         country  \
# 0     brendan gleeson, taylor kitsch, gordon pinsent          canada
# 1   mahesh manjrekar, abhay mahajan, sachin khedekar           india
# 2  tom sizemore, lorenzo lamas, robert lasardo, r...   united states
# 3  interviews with: pink, adele, beyoncé, britney...   united states
# 4  harry dean stanton, kieran o'brien, george cos...  united kingdom
#
#    date_added  release_year rating duration                listed_in  \
# 0  2021-03-30          2014      g  113 min            comedy, drama
# 1  2021-03-30          2018    13+  110 min     drama, international
# 2  2021-03-30          2017      g   74 min  action, drama, suspense
# 3  2021-03-30          2014      g   69 min              documentary
# 4  2021-03-30          1989      g   45 min           drama, fantasy
#
#                                          description  score  duration_int  \
# 0  a small fishing village must procure a local d...     99           113
# 1  a metro family decides to fight a cyber crimin...     37           110
# 2  after a man discovers his wife is cheating on ...     20            74
# 3  pink breaks the mold once again, bringing her ...     27            69
# 4  teenage matt banting wants to work with a famo...     75            45
#
#   duration_type
# 0           min
# 1           min
# 2           min
# 3           min
# 4           min

# %% [markdown]
# ### Dataset *'Disney'*

# %%
disney_plus = pd.read_csv('https://raw.githubusercontent.com/HX-FNegrete/PI01-Data-Engineering/main/Datasets/disney_plus_titles-score.csv')
disney_plus.head()
# Out:
#   show_id     type                                             title  \
# 0      s1    Movie  Duck the Halls: A Mickey Mouse Christmas Special
# 1      s2    Movie                            Ernest Saves Christmas
# 2      s3    Movie                      Ice Age: A Mammoth Christmas
# 3      s4    Movie                        The Queen Family Singalong
# 4      s5  TV Show                             The Beatles: Get Back
#
#                             director  \
# 0  Alonso Ramirez Ramos, Dave Wasson
# 1                        John Cherry
# 2                       Karen Disher
# 3                    Hamish Hamilton
# 4                                NaN
#
#                                                 cast        country  \
# 0  Chris Diamantopoulos, Tony Anselmo, Tress MacN...            NaN
# 1           Jim Varney, Noelle Parker, Douglas Seale            NaN
# 2  Raymond Albert Romano, John Leguizamo, Denis L...  United States
# 3  Darren Criss, Adam Lambert, Derek Hough, Alexa...            NaN
# 4  John Lennon, Paul McCartney, George Harrison, ...            NaN
#
#           date_added  release_year rating  duration  \
# 0  November 26, 2021          2016   TV-G    23 min
# 1  November 26, 2021          1988     PG    91 min
# 2  November 26, 2021          2011   TV-G    23 min
# 3  November 26, 2021          2021  TV-PG    41 min
# 4  November 25, 2021          2021    NaN  1 Season
#
#                        listed_in  \
# 0              Animation, Family
# 1                         Comedy
# 2      Animation, Comedy, Family
# 3                        Musical
# 4  Docuseries, Historical, Music
#
#                                          description  score
# 0   Join Mickey and the gang as they duck the halls!    100
# 1  Santa Claus passes his magic bag to a new St. ...     17
# 2          Sid the Sloth is on Santa's naughty list.     92
# 3               This is real life, not just fantasy!     35
# 4  A three-part documentary from Peter Jackson ca...     11

# %%
print('Cantidad de Filas y columnas:',disney_plus.shape)
# Out:
# Cantidad de Filas y columnas: (1450, 13)

# %%
print('Nombre columnas:',disney_plus.columns)
# Out:
# Nombre columnas: Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description',
#        'score'],
#       dtype='object')

# %%
disney_plus.isnull().sum()
# Out:
# show_id           0
# type              0
# title             0
# director        473
# cast            190
# country         219
# date_added        3
# release_year      0
# rating            3
# duration          0
# listed_in         0
# description       0
# score             0
# dtype: int64

# %%
disney_plus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1450 entries, 0 to 1449
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       1450 non-null   object
#  1   type          1450 non-null   object
#  2   title         1450 non-null   object
#  3   director      977 non-null    object
#  4   cast          1260 non-null   object
#  5   country       1231 non-null   object
#  6   date_added    1447 non-null   object
#  7   release_year  1450 non-null   int64
#  8   rating        1447 non-null   object
#  9   duration      1450 non-null   object
#  10  listed_in     1450 non-null   object
#  11  description   1450 non-null   object
#  12  score         1450 non-null   int64
# dtypes: int64(2), object(11)
# memory usage: 147.4+ KB

# %% [markdown]
# #### ``` 1. Generando campo id = "d" + show_id ```

# %%
# Agregar "d" delante de cada valor en la columna "show_id"
disney_plus["show_id"] = disney_plus["show_id"].apply(lambda x: "d" + x)

# %%
disney_plus.head()
# Out:
#   show_id     type                                             title  \
# 0     ds1    Movie  Duck the Halls: A Mickey Mouse Christmas Special
# 1     ds2    Movie                            Ernest Saves Christmas
# 2     ds3    Movie                      Ice Age: A Mammoth Christmas
# 3     ds4    Movie                        The Queen Family Singalong
# 4     ds5  TV Show                             The Beatles: Get Back
#
#                             director  \
# 0  Alonso Ramirez Ramos, Dave Wasson
# 1                        John Cherry
# 2                       Karen Disher
# 3                    Hamish Hamilton
# 4                                NaN
#
#                                                 cast        country  \
# 0  Chris Diamantopoulos, Tony Anselmo, Tress MacN...            NaN
# 1           Jim Varney, Noelle Parker, Douglas Seale            NaN
# 2  Raymond Albert Romano, John Leguizamo, Denis L...  United States
# 3  Darren Criss, Adam Lambert, Derek Hough, Alexa...            NaN
# 4  John Lennon, Paul McCartney, George Harrison, ...            NaN
#
#           date_added  release_year rating  duration  \
# 0  November 26, 2021          2016   TV-G    23 min
# 1  November 26, 2021          1988     PG    91 min
# 2  November 26, 2021          2011   TV-G    23 min
# 3  November 26, 2021          2021  TV-PG    41 min
# 4  November 25, 2021          2021    NaN  1 Season
#
#                        listed_in  \
# 0              Animation, Family
# 1                         Comedy
# 2      Animation, Comedy, Family
# 3                        Musical
# 4  Docuseries, Historical, Music
#
#                                          description  score
# 0   Join Mickey and the gang as they duck the halls!    100
# 1  Santa Claus passes his magic bag to a new St. ...     17
# 2          Sid the Sloth is on Santa's naughty list.     92
# 3               This is real life, not just fantasy!     35
# 4  A three-part documentary from Peter Jackson ca...     11

# %% [markdown]
# #### ``` 2. Reemplazando los valores nulos del campo 'rating' por el string “g” ```

# %%
disney_plus['rating'].fillna('g', inplace=True)

# %% [markdown]
# #### Verificando que se hayan reemplazado todos los valores nulos:

# %%
disney_plus['rating'].isna().count()
# Out:
# 1450

# %% [markdown]
# #### ``` 3. De haber fechas, deberán tener el formato AAAA-mm-dd ```

# %%
disney_plus['date_added'] = pd.to_datetime(disney_plus['date_added'], format='%B %d, %Y').dt.strftime('%Y-%m-%d')

# %% [markdown]
# #### Verificando cambio de formato en la columna 'date_added'

# %%
disney_plus.head(10)
# Out:
#   show_id     type                                             title  \
# 0     ds1    Movie  Duck the Halls: A Mickey Mouse Christmas Special
# 1     ds2    Movie                            Ernest Saves Christmas
# 2     ds3    Movie                      Ice Age: A Mammoth Christmas
# 3     ds4    Movie                        The Queen Family Singalong
# 4     ds5  TV Show                             The Beatles: Get Back
# 5     ds6    Movie                                 Becoming Cousteau
# 6     ds7  TV Show                                           Hawkeye
# 7     ds8  TV Show                            Port Protection Alaska
# 8     ds9  TV Show                         Secrets of the Zoo: Tampa
# 9    ds10    Movie             A Muppets Christmas: Letters To Santa
#
#                             director  \
# 0  Alonso Ramirez Ramos, Dave Wasson
# 1                        John Cherry
# 2                       Karen Disher
# 3                    Hamish Hamilton
# 4                                NaN
# 5                         Liz Garbus
# 6                                NaN
# 7                                NaN
# 8                                NaN
# 9                   Kirk R. Thatcher
#
#                                                 cast        country  \
# 0  Chris Diamantopoulos, Tony Anselmo, Tress MacN...            NaN
# 1           Jim Varney, Noelle Parker, Douglas Seale            NaN
# 2  Raymond Albert Romano, John Leguizamo, Denis L...  United States
# 3  Darren Criss, Adam Lambert, Derek Hough, Alexa...            NaN
# 4  John Lennon, Paul McCartney, George Harrison, ...            NaN
# 5              Jacques Yves Cousteau, Vincent Cassel  United States
# 6  Jeremy Renner, Hailee Steinfeld, Vera Farmiga,...            NaN
# 7  Gary Muehlberger, Mary Miller, Curly Leach, Sa...  United States
# 8  Dr. Ray Ball, Dr. Lauren Smith, Chris Massaro,...  United States
# 9  Steve Whitmire, Dave Goelz, Bill Barretta, Eri...  United States
#
#    date_added  release_year rating   duration  \
# 0  2021-11-26          2016   TV-G     23 min
# 1  2021-11-26          1988     PG     91 min
# 2  2021-11-26          2011   TV-G     23 min
# 3  2021-11-26          2021  TV-PG     41 min
# 4  2021-11-25          2021      g   1 Season
# 5  2021-11-24          2021  PG-13     94 min
# 6  2021-11-24          2021  TV-14   1 Season
# 7  2021-11-24          2015  TV-14  2 Seasons
# 8  2021-11-24          2019  TV-PG  2 Seasons
# 9  2021-11-19          2008      G     45 min
#
#                               listed_in  \
# 0                     Animation, Family
# 1                                Comedy
# 2             Animation, Comedy, Family
# 3                               Musical
# 4         Docuseries, Historical, Music
# 5             Biographical, Documentary
# 6           Action-Adventure, Superhero
# 7         Docuseries, Reality, Survival
# 8  Animals & Nature, Docuseries, Family
# 9               Comedy, Family, Musical
#
#                                          description  score
# 0   Join Mickey and the gang as they duck the halls!    100
# 1  Santa Claus passes his magic bag to a new St. ...     17
# 2          Sid the Sloth is on Santa's naughty list.     92
# 3               This is real life, not just fantasy!     35
# 4  A three-part documentary from Peter Jackson ca...     11
# 5  An inside look at the legendary life of advent...     18
# 6  Clint Barton/Hawkeye must team up with skilled...     98
# 7  Residents of Port Protection must combat volat...     60
# 8  A day in the life at ZooTampa is anything but ...     53
# 9  Celebrate the holiday season with all your fav...      7

# %% [markdown]
# #### ``` 4. Los campos de texto deberán estar en minúsculas, sin excepciones ```

# %%
disney = disney_plus.applymap(lambda x: str(x).lower() if type(x) == str else x)

# %% [markdown]
# #### Verificando

# %%
disney.head()
# Out:
#   show_id     type                                             title  \
# 0     ds1    movie  duck the halls: a mickey mouse christmas special
# 1     ds2    movie                            ernest saves christmas
# 2     ds3    movie                      ice age: a mammoth christmas
# 3     ds4    movie                        the queen family singalong
# 4     ds5  tv show                             the beatles: get back
#
#                             director  \
# 0  alonso ramirez ramos, dave wasson
# 1                        john cherry
# 2                       karen disher
# 3                    hamish hamilton
# 4                                NaN
#
#                                                 cast        country  \
# 0  chris diamantopoulos, tony anselmo, tress macn...            NaN
# 1           jim varney, noelle parker, douglas seale            NaN
# 2  raymond albert romano, john leguizamo, denis l...  united states
# 3  darren criss, adam lambert, derek hough, alexa...            NaN
# 4  john lennon, paul mccartney, george harrison, ...            NaN
#
#    date_added  release_year rating  duration                      listed_in  \
# 0  2021-11-26          2016   tv-g    23 min              animation, family
# 1  2021-11-26          1988     pg    91 min                         comedy
# 2  2021-11-26          2011   tv-g    23 min      animation, comedy, family
# 3  2021-11-26          2021  tv-pg    41 min                        musical
# 4  2021-11-25          2021      g  1 season  docuseries, historical, music
#
#                                          description  score
# 0   join mickey and the gang as they duck the halls!    100
# 1  santa claus passes his magic bag to a new st. ...     17
# 2          sid the sloth is on santa's naughty list.     92
# 3               this is real life, not just fantasy!     35
# 4  a three-part documentary from peter jackson ca...     11

# %% [markdown]
# #### ``` 5. El campo duration debe convertirse en dos campos: duration_int y duration_type. El primero será un integer y el segundo un string indicando la unidad de medición de duración: min (minutos) o season (temporadas) ```

# %% [markdown]
# #### Cambiando seasons a season

# %%
disney['duration'] = disney['duration'].str.replace('seasons', 'season')

# %% [markdown]
# #### Transformando 'duration' a 'duration_int','duration_type'

# %%
disney[['duration_int','duration_type']] = disney['duration'].str.split(n=1,expand=True)
disney['duration_int'] = disney['duration_int'].astype(int)

# %% [markdown]
# #### Verificando

# %%
disney.head()
# Out:
#   show_id     type                                             title  \
# 0     ds1    movie  duck the halls: a mickey mouse christmas special
# 1     ds2    movie                            ernest saves christmas
# 2     ds3    movie                      ice age: a mammoth christmas
# 3     ds4    movie                        the queen family singalong
# 4     ds5  tv show                             the beatles: get back
#
#                             director  \
# 0  alonso ramirez ramos, dave wasson
# 1                        john cherry
# 2                       karen disher
# 3                    hamish hamilton
# 4                                NaN
#
#                                                 cast        country  \
# 0  chris diamantopoulos, tony anselmo, tress macn...            NaN
# 1           jim varney, noelle parker, douglas seale            NaN
# 2  raymond albert romano, john leguizamo, denis l...  united states
# 3  darren criss, adam lambert, derek hough, alexa...            NaN
# 4  john lennon, paul mccartney, george harrison, ...            NaN
#
#    date_added  release_year rating  duration                      listed_in  \
# 0  2021-11-26          2016   tv-g    23 min              animation, family
# 1  2021-11-26          1988     pg    91 min                         comedy
# 2  2021-11-26          2011   tv-g    23 min      animation, comedy, family
# 3  2021-11-26          2021  tv-pg    41 min                        musical
# 4  2021-11-25          2021      g  1 season  docuseries, historical, music
#
#                                          description  score  duration_int  \
# 0   join mickey and the gang as they duck the halls!    100            23
# 1  santa claus passes his magic bag to a new st. ...     17            91
# 2          sid the sloth is on santa's naughty list.     92            23
# 3               this is real life, not just fantasy!     35            41
# 4  a three-part documentary from peter jackson ca...     11             1
#
#   duration_type
# 0           min
# 1           min
# 2           min
# 3           min
# 4        season

# %% [markdown]
# ### Dataset *'Hulu'*

# %%
hulu = pd.read_csv('https://raw.githubusercontent.com/HX-FNegrete/PI01-Data-Engineering/main/Datasets/hulu_titles-score%20(2).csv')
hulu.head()
# Out:
#   show_id   type                           title director  cast country  \
# 0      s1  Movie  Ricky Velez: Here's Everything      NaN   NaN     NaN
# 1      s2  Movie                    Silent Night      NaN   NaN     NaN
# 2      s3  Movie                    The Marksman      NaN   NaN     NaN
# 3      s4  Movie                            Gaia      NaN   NaN     NaN
# 4      s5  Movie                        Settlers      NaN   NaN     NaN
#
#          date_added  release_year rating duration                  listed_in  \
# 0  October 24, 2021          2021  TV-MA      NaN           Comedy, Stand Up
# 1  October 23, 2021          2020    NaN   94 min     Crime, Drama, Thriller
# 2  October 23, 2021          2021  PG-13  108 min           Action, Thriller
# 3  October 22, 2021          2021      R   97 min                     Horror
# 4  October 22, 2021          2021    NaN  104 min  Science Fiction, Thriller
#
#                                          description  score
# 0  ​Comedian Ricky Velez bares it all with his ho...     48
# 1  Mark, a low end South London hitman recently r...      8
# 2  A hardened Arizona rancher tries to protect an...      8
# 3  A forest ranger and two survivalists with a cu...     33
# 4  Mankind's earliest settlers on the Martian fro...     24

# %%
print('Cantidad de Filas y columnas:',hulu.shape)
# Out:
# Cantidad de Filas y columnas: (3073, 13)

# %%
print('Nombre columnas:',hulu.columns)
# Out:
# Nombre columnas: Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description',
#        'score'],
#       dtype='object')

# %%
hulu.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        3070
# cast            3073
# country         1453
# date_added        28
# release_year       0
# rating           520
# duration         479
# listed_in          0
# description        4
# score              0
# dtype: int64

# %%
hulu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3073 entries, 0 to 3072
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       3073 non-null   object
#  1   type          3073 non-null   object
#  2   title         3073 non-null   object
#  3   director      3 non-null      object
#  4   cast          0 non-null      float64
#  5   country       1620 non-null   object
#  6   date_added    3045 non-null   object
#  7   release_year  3073 non-null   int64
#  8   rating        2553 non-null   object
#  9   duration      2594 non-null   object
#  10  listed_in     3073 non-null   object
#  11  description   3069 non-null   object
#  12  score         3073 non-null   int64
# dtypes: float64(1), int64(2), object(10)
# memory usage: 312.2+ KB

# %% [markdown]
# #### ``` 1. Generando campo id = "h" + show_id ```

# %%
# Agregar "d" delante de cada valor en la columna "show_id"
hulu["show_id"] = hulu["show_id"].apply(lambda x: "h" + x)

# %%
hulu.head()
# Out:
#   show_id   type                           title director  cast country  \
# 0     hs1  Movie  Ricky Velez: Here's Everything      NaN   NaN     NaN
# 1     hs2  Movie                    Silent Night      NaN   NaN     NaN
# 2     hs3  Movie                    The Marksman      NaN   NaN     NaN
# 3     hs4  Movie                            Gaia      NaN   NaN     NaN
# 4     hs5  Movie                        Settlers      NaN   NaN     NaN
#
#          date_added  release_year rating duration                  listed_in  \
# 0  October 24, 2021          2021  TV-MA      NaN           Comedy, Stand Up
# 1  October 23, 2021          2020    NaN   94 min     Crime, Drama, Thriller
# 2  October 23, 2021          2021  PG-13  108 min           Action, Thriller
# 3  October 22, 2021          2021      R   97 min                     Horror
# 4  October 22, 2021          2021    NaN  104 min  Science Fiction, Thriller
#
#                                          description  score
# 0  ​Comedian Ricky Velez bares it all with his ho...     48
# 1  Mark, a low end South London hitman recently r...      8
# 2  A hardened Arizona rancher tries to protect an...      8
# 3  A forest ranger and two survivalists with a cu...     33
# 4  Mankind's earliest settlers on the Martian fro...     24

# %% [markdown]
# #### ``` 2. Reemplazando los valores nulos del campo 'rating' por el string “g” ```

# %%
hulu['rating'].fillna('g', inplace=True)

# %% [markdown]
# #### Verificando que se hayan reemplazado todos los valores nulos:

# %%
hulu['rating'].isna().count()
# Out:
# 3073

# %% [markdown]
# #### ``` 3. De haber fechas, deberán tener el formato AAAA-mm-dd ```

# %%
hulu['date_added'] = pd.to_datetime(hulu['date_added'], format='%B %d, %Y').dt.strftime('%Y-%m-%d')

# %% [markdown]
# #### Verificando cambio de formato en la columna 'date_added'

# %%
hulu.head(10)
# Out:
#   show_id     type                           title director  cast  \
# 0     hs1    Movie  Ricky Velez: Here's Everything      NaN   NaN
# 1     hs2    Movie                    Silent Night      NaN   NaN
# 2     hs3    Movie                    The Marksman      NaN   NaN
# 3     hs4    Movie                            Gaia      NaN   NaN
# 4     hs5    Movie                        Settlers      NaN   NaN
# 5     hs6  TV Show   The Halloween Candy Magic Pet      NaN   NaN
# 6     hs7    Movie              The Evil Next Door      NaN   NaN
# 7     hs8  TV Show          The Next Thing You Eat      NaN   NaN
# 8     hs9  TV Show                          Queens      NaN   NaN
# 9    hs10  TV Show                The Bachelorette      NaN   NaN
#
#          country  date_added  release_year rating   duration  \
# 0            NaN  2021-10-24          2021  TV-MA        NaN
# 1            NaN  2021-10-23          2020      g     94 min
# 2            NaN  2021-10-23          2021  PG-13    108 min
# 3            NaN  2021-10-22          2021      R     97 min
# 4            NaN  2021-10-22          2021      g    104 min
# 5            NaN  2021-10-22          2021      g   1 Season
# 6            NaN  2021-10-21          2020      g     88 min
# 7            NaN  2021-10-21          2021      g   1 Season
# 8            NaN  2021-10-20          2021  TV-14   1 Season
# 9  United States  2021-10-20          2003  TV-14  3 Seasons
#
#                                            listed_in  \
# 0                                   Comedy, Stand Up
# 1                             Crime, Drama, Thriller
# 2                                   Action, Thriller
# 3                                             Horror
# 4                          Science Fiction, Thriller
# 5                                       Family, Kids
# 6                                   Horror, Thriller
# 7  Cooking & Food, Documentaries, Lifestyle & Cul...
# 8                                       Drama, Music
# 9                                   Reality, Romance
#
#                                          description  score
# 0  ​Comedian Ricky Velez bares it all with his ho...     48
# 1  Mark, a low end South London hitman recently r...      8
# 2  A hardened Arizona rancher tries to protect an...      8
# 3  A forest ranger and two survivalists with a cu...     33
# 4  Mankind's earliest settlers on the Martian fro...     24
# 5  Join Mila and Morphle on a mystery-filled Hall...     45
# 6  New to her role as a stepmom, a young woman mo...     37
# 7  With the unique insights and experience of Ugl...     76
# 8  Four women in their 40s reunite for a chance t...     57
# 9  ABC's romance reality show lets one lucky lady...     79

# %% [markdown]
# #### ``` 4. Los campos de texto deberán estar en minúsculas, sin excepciones ```

# %%
hulu = hulu.applymap(lambda x: str(x).lower() if type(x) == str else x)

# %% [markdown]
# #### Verificando

# %%
hulu.head()
# Out:
#   show_id   type                           title director  cast country  \
# 0     hs1  movie  ricky velez: here's everything      NaN   NaN     NaN
# 1     hs2  movie                    silent night      NaN   NaN     NaN
# 2     hs3  movie                    the marksman      NaN   NaN     NaN
# 3     hs4  movie                            gaia      NaN   NaN     NaN
# 4     hs5  movie                        settlers      NaN   NaN     NaN
#
#    date_added  release_year rating duration                  listed_in  \
# 0  2021-10-24          2021  tv-ma      NaN           comedy, stand up
# 1  2021-10-23          2020      g   94 min     crime, drama, thriller
# 2  2021-10-23          2021  pg-13  108 min           action, thriller
# 3  2021-10-22          2021      r   97 min                     horror
# 4  2021-10-22          2021      g  104 min  science fiction, thriller
#
#                                          description  score
# 0  ​comedian ricky velez bares it all with his ho...     48
# 1  mark, a low end south london hitman recently r...      8
# 2  a hardened arizona rancher tries to protect an...      8
# 3  a forest ranger and two survivalists with a cu...     33
# 4  mankind's earliest settlers on the martian fro...     24

# %% [markdown]
# #### ``` 5. El campo duration debe convertirse en dos campos: duration_int y duration_type. El primero será un integer y el segundo un string indicando la unidad de medición de duración: min (minutos) o season (temporadas) ```

# %% [markdown]
# #### Cambiando seasons a season

# %%
hulu['duration'] = hulu['duration'].str.replace('seasons', 'season')

# %% [markdown]
# #### Primero reemplazamos los NaN en 'duration' a "0 min"

# %%
hulu['duration'].fillna("0 min", inplace=True)

# %% [markdown]
# #### Transformando 'duration' a 'duration_int','duration_type'

# %%
#Ahora si realizamos la conversión de 'duration' a 'duration_int','duration_type'
hulu[['duration_int','duration_type']] = hulu['duration'].str.split(n=1,expand=True)
hulu['duration_int'] = hulu['duration_int'].astype(int)

# %% [markdown]
# #### Verificando

# %%
hulu.head()
# Out:
#   show_id   type                           title director  cast country  \
# 0     hs1  movie  ricky velez: here's everything      NaN   NaN     NaN
# 1     hs2  movie                    silent night      NaN   NaN     NaN
# 2     hs3  movie                    the marksman      NaN   NaN     NaN
# 3     hs4  movie                            gaia      NaN   NaN     NaN
# 4     hs5  movie                        settlers      NaN   NaN     NaN
#
#    date_added  release_year rating duration                  listed_in  \
# 0  2021-10-24          2021  tv-ma    0 min           comedy, stand up
# 1  2021-10-23          2020      g   94 min     crime, drama, thriller
# 2  2021-10-23          2021  pg-13  108 min           action, thriller
# 3  2021-10-22          2021      r   97 min                     horror
# 4  2021-10-22          2021      g  104 min  science fiction, thriller
#
#                                          description  score  duration_int  \
# 0  ​comedian ricky velez bares it all with his ho...     48             0
# 1  mark, a low end south london hitman recently r...      8            94
# 2  a hardened arizona rancher tries to protect an...      8           108
# 3  a forest ranger and two survivalists with a cu...     33            97
# 4  mankind's earliest settlers on the martian fro...     24           104
#
#   duration_type
# 0           min
# 1           min
# 2           min
# 3           min
# 4           min

# %% [markdown]
# ### Dataset *'Netflix'*

# %%
netflix = pd.read_csv('https://raw.githubusercontent.com/HX-FNegrete/PI01-Data-Engineering/main/Datasets/netflix_titles-score.csv')
netflix.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description  score
# 0  As her father nears the end of his life, filmm...     29
# 1  After crossing paths at a party, a Cape Town t...     86
# 2  To protect his family from a powerful drug lor...     75
# 3  Feuds, flirtations and toilet talk go down amo...     49
# 4  In a city of coaching centers known to train I...     92

# %%
print('Cantidad de Filas y columnas:',netflix.shape)
# Out:
# Cantidad de Filas y columnas: (8807, 13)

# %%
print('Nombre columnas:',netflix.columns)
# Out:
# Nombre columnas: Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description',
#        'score'],
#       dtype='object')

# %%
netflix.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# score              0
# dtype: int64

# %%
netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
#  12  score         8807 non-null   int64
# dtypes: int64(2), object(11)
# memory usage: 894.6+ KB

# %% [markdown]
# #### ``` 1. Generando campo id = "n" + show_id ```

# %%
# Agregar "d" delante de cada valor en la columna "show_id"
netflix["show_id"] = netflix["show_id"].apply(lambda x: "n" + x)

# %%
netflix.head()
# Out:
#   show_id     type                  title         director  \
# 0     ns1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1     ns2  TV Show          Blood & Water              NaN
# 2     ns3  TV Show              Ganglands  Julien Leclercq
# 3     ns4  TV Show  Jailbirds New Orleans              NaN
# 4     ns5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description  score
# 0  As her father nears the end of his life, filmm...     29
# 1  After crossing paths at a party, a Cape Town t...     86
# 2  To protect his family from a powerful drug lor...     75
# 3  Feuds, flirtations and toilet talk go down amo...     49
# 4  In a city of coaching centers known to train I...     92

# %% [markdown]
# #### ``` 2. Reemplazando los valores nulos del campo 'rating' por el string “g”  ```

# %%
netflix['rating'].fillna('g', inplace=True)

# %% [markdown]
# #### Verificando que se hayan reemplazado todos los valores nulos:

# %%
netflix['rating'].isna().count()
# Out:
# 8807

# %% [markdown]
# #### ``` 3. De haber fechas, deberán tener el formato AAAA-mm-dd ```

# %%
#Primero igualamos el formato de la data en la columna 'date_added' para eliminar los espacios en blanco al principio y al final de cada valor en la columna
netflix['date_added'] = netflix['date_added'].str.strip()

# %%
netflix['date_added'] = pd.to_datetime(netflix['date_added'], format='%B %d, %Y').dt.strftime('%Y-%m-%d')

# %% [markdown]
# #### Verificando cambio de formato en la columna 'date_added'

# %%
netflix.head(10)
# Out:
#   show_id     type                             title  \
# 0     ns1    Movie              Dick Johnson Is Dead
# 1     ns2  TV Show                     Blood & Water
# 2     ns3  TV Show                         Ganglands
# 3     ns4  TV Show             Jailbirds New Orleans
# 4     ns5  TV Show                      Kota Factory
# 5     ns6  TV Show                     Midnight Mass
# 6     ns7    Movie  My Little Pony: A New Generation
# 7     ns8    Movie                           Sankofa
# 8     ns9  TV Show     The Great British Baking Show
# 9    ns10    Movie                      The Starling
#
#                         director  \
# 0                Kirsten Johnson
# 1                            NaN
# 2                Julien Leclercq
# 3                            NaN
# 4                            NaN
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
# 8                Andy Devonshire
# 9                 Theodore Melfi
#
#                                                 cast  \
# 0                                                NaN
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# 3                                                NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...
# 6  Vanessa Hudgens, Kimiko Glenn, James Marsden, ...
# 7  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# 9  Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
#
#                                              country  date_added  \
# 0                                      United States  2021-09-25
# 1                                       South Africa  2021-09-24
# 2                                                NaN  2021-09-24
# 3                                                NaN  2021-09-24
# 4                                              India  2021-09-24
# 5                                                NaN  2021-09-24
# 6                                                NaN  2021-09-24
# 7  United States, Ghana, Burkina Faso, United Kin...  2021-09-24
# 8                                     United Kingdom  2021-09-24
# 9                                      United States  2021-09-24
#
#    release_year rating   duration  \
# 0          2020  PG-13     90 min
# 1          2021  TV-MA  2 Seasons
# 2          2021  TV-MA   1 Season
# 3          2021  TV-MA   1 Season
# 4          2021  TV-MA  2 Seasons
# 5          2021  TV-MA   1 Season
# 6          2021     PG     91 min
# 7          1993  TV-MA    125 min
# 8          2021  TV-14  9 Seasons
# 9          2021  PG-13    104 min
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
# 5                 TV Dramas, TV Horror, TV Mysteries
# 6                           Children & Family Movies
# 7   Dramas, Independent Movies, International Movies
# 8                       British TV Shows, Reality TV
# 9                                   Comedies, Dramas
#
#                                          description  score
# 0  As her father nears the end of his life, filmm...     29
# 1  After crossing paths at a party, a Cape Town t...     86
# 2  To protect his family from a powerful drug lor...     75
# 3  Feuds, flirtations and toilet talk go down amo...     49
# 4  In a city of coaching centers known to train I...     92
# 5  The arrival of a charismatic young priest brin...     37
# 6  Equestria's divided. But a bright-eyed hero be...     12
# 7  On a photo shoot in Ghana, an American model s...     10
# 8  A talented batch of amateur bakers face off in...     44
# 9  A woman adjusting to life after a loss contend...      3

# %% [markdown]
# #### ``` 4. Los campos de texto deberán estar en minúsculas, sin excepciones ```

# %%
netflix = netflix.applymap(lambda x: str(x).lower() if type(x) == str else x)

# %% [markdown]
# #### Verificando

# %%
netflix.head()
# Out:
#   show_id     type                  title         director  \
# 0     ns1    movie   dick johnson is dead  kirsten johnson
# 1     ns2  tv show          blood & water              NaN
# 2     ns3  tv show              ganglands  julien leclercq
# 3     ns4  tv show  jailbirds new orleans              NaN
# 4     ns5  tv show           kota factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  united states
# 1  ama qamata, khosi ngema, gail mabalane, thaban...   south africa
# 2  sami bouajila, tracy gotoas, samuel jouy, nabi...            NaN
# 3                                                NaN            NaN
# 4  mayur more, jitendra kumar, ranjan raj, alam k...          india
#
#    date_added  release_year rating   duration  \
# 0  2021-09-25          2020  pg-13     90 min
# 1  2021-09-24          2021  tv-ma  2 seasons
# 2  2021-09-24          2021  tv-ma   1 season
# 3  2021-09-24          2021  tv-ma   1 season
# 4  2021-09-24          2021  tv-ma  2 seasons
#
#                                            listed_in  \
# 0                                      documentaries
# 1    international tv shows, tv dramas, tv mysteries
# 2  crime tv shows, international tv shows, tv act...
# 3                             docuseries, reality tv
# 4  international tv shows, romantic tv shows, tv ...
#
#                                          description  score
# 0  as her father nears the end of his life, filmm...     29
# 1  after crossing paths at a party, a cape town t...     86
# 2  to protect his family from a powerful drug lor...     75
# 3  feuds, flirtations and toilet talk go down amo...     49
# 4  in a city of coaching centers known to train i...     92

# %% [markdown]
# #### ``` 5. El campo duration debe convertirse en dos campos: duration_int y duration_type. El primero será un integer y el segundo un string indicando la unidad de medición de duración: min (minutos) o season (temporadas) ```

# %% [markdown]
# #### Cambiando seasons a season

# %%
netflix['duration'] = netflix['duration'].str.replace('seasons', 'season')

# %% [markdown]
# #### Primero reemplazamos los NaN en 'duration' a "0 min"

# %%
netflix['duration'].fillna("0 min", inplace=True)

# %% [markdown]
# #### Transformando 'duration' a 'duration_int','duration_type'

# %%
netflix[['duration_int','duration_type']] = netflix['duration'].str.split(n=1,expand=True)
netflix['duration_int'] = netflix['duration_int'].astype(int)

# %% [markdown]
# #### Verificando

# %%
netflix.head()
# Out:
#   show_id     type                  title         director  \
# 0     ns1    movie   dick johnson is dead  kirsten johnson
# 1     ns2  tv show          blood & water              NaN
# 2     ns3  tv show              ganglands  julien leclercq
# 3     ns4  tv show  jailbirds new orleans              NaN
# 4     ns5  tv show           kota factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  united states
# 1  ama qamata, khosi ngema, gail mabalane, thaban...   south africa
# 2  sami bouajila, tracy gotoas, samuel jouy, nabi...            NaN
# 3                                                NaN            NaN
# 4  mayur more, jitendra kumar, ranjan raj, alam k...          india
#
#    date_added  release_year rating  duration  \
# 0  2021-09-25          2020  pg-13    90 min
# 1  2021-09-24          2021  tv-ma  2 season
# 2  2021-09-24          2021  tv-ma  1 season
# 3  2021-09-24          2021  tv-ma  1 season
# 4  2021-09-24          2021  tv-ma  2 season
#
#                                            listed_in  \
# 0                                      documentaries
# 1    international tv shows, tv dramas, tv mysteries
# 2  crime tv shows, international tv shows, tv act...
# 3                             docuseries, reality tv
# 4  international tv shows, romantic tv shows, tv ...
#
#                                          description  score  duration_int  \
# 0  as her father nears the end of his life, filmm...     29            90
# 1  after crossing paths at a party, a cape town t...     86             2
# 2  to protect his family from a powerful drug lor...     75             1
# 3  feuds, flirtations and toilet talk go down amo...     49             1
# 4  in a city of coaching centers known to train i...     92             2
#
#   duration_type
# 0           min
# 1        season
# 2        season
# 3        season
# 4        season

# %% [markdown]
# ## <center>  *¿Qué sacamos del EDA y ETL?*</center>
# #### - El EDA será entonces una primer aproximación a los datos, ***atención***, si estamos más o menos bien preparados y suponiendo una muestra de datos “suficiente”, puede que en “unas horas” tengamos ya varias conclusiones como por ejemplo:
# #### - A estas alturas podemos saber si nos están pidiendo algo viable ó si necesitamos más datos para comenzar.
# #### - El EDA debe tomar horas, ó puede que un día, pero la idea es poder sacar algunas conclusiones rápidas para contestar al cliente si podemos seguir o no con su propuesta.

# %% [markdown]
# # *Resultado:*
# ### - Se realizo las transformaciones asignadas

# %% [markdown]
# ### Concatenamos los 4 datasets

# %%
all_app = pd.concat([amazon, disney, hulu, netflix], axis=0)
all_app.head()
# Out:
#   show_id   type                 title        director  \
# 0     as1  movie   the grand seduction    don mckellar
# 1     as2  movie  take care good night    girish joshi
# 2     as3  movie  secrets of deception     josh webber
# 3     as4  movie    pink: staying true  sonia anderson
# 4     as5  movie         monster maker    giles foster
#
#                                                 cast         country  \
# 0     brendan gleeson, taylor kitsch, gordon pinsent          canada
# 1   mahesh manjrekar, abhay mahajan, sachin khedekar           india
# 2  tom sizemore, lorenzo lamas, robert lasardo, r...   united states
# 3  interviews with: pink, adele, beyoncé, britney...   united states
# 4  harry dean stanton, kieran o'brien, george cos...  united kingdom
#
#    date_added  release_year rating duration                listed_in  \
# 0  2021-03-30          2014      g  113 min            comedy, drama
# 1  2021-03-30          2018    13+  110 min     drama, international
# 2  2021-03-30          2017      g   74 min  action, drama, suspense
# 3  2021-03-30          2014      g   69 min              documentary
# 4  2021-03-30          1989      g   45 min           drama, fantasy
#
#                                          description  score  duration_int  \
# 0  a small fishing village must procure a local d...     99           113
# 1  a metro family decides to fight a cyber crimin...     37           110
# 2  after a man discovers his wife is cheating on ...     20            74
# 3  pink breaks the mold once again, bringing her ...     27            69
# 4  teenage matt banting wants to work with a famo...     75            45
#
#   duration_type
# 0           min
# 1           min
# 2           min
# 3           min
# 4           min

# %% [markdown]
# ### Conservo la data en formato *'CSV'*

# %%
all_app.to_csv('C:/ProgramData/MySQL/MySQL Server 8.0/Uploads/platforms_final.csv', index=False, encoding='utf-8-sig')
